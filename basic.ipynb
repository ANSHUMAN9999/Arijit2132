# %% [markdown]
# <a href="https://colab.research.google.com/github/ANSHUMAN9999/Arijit2132/blob/main/basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a program hello world.

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Write a program two numbers and print sum.

# %%
a=10
b=30
print(a+b)
# Out:
# 40

# %% [markdown]
# Write a program to read two numbers and print their sum,difference,product and qutient

# %%
a=50
b=30
print(a-b)
# Out:
# 20

# %%
p=80
q=40
print(p*q)
# Out:
# 3200

# %%
s=30
t=25
print(s/t)
# Out:
# 1.2

# %%
r=float(input("enter a radius"))
area=3.14*r*r
circuference=2*3.14*r
print(area)
print(circuference)
# Out:
# enter a radius50
# 7850.0
# 314.0

# %%
length=int(input("enter a length"))
breadth=int(input("enter a breadth"))

area=length*breadth
perimeter=2*length*breadth

print(area)
print(perimeter)
# Out:
# enter a length15
# enter a breadth12
# 180
# 360

# %%
a=10
b=20
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# 20
# 10

# %%
a=50
b=20
a,b=b,a
print(a)
print(b)
# Out:
# 20
# 50

# %%
a=10
b=20
c=30
avgereg=(a+b+c)/3
print(avgereg)
# Out:
# 20.0

# %%
length=int(input("enter a lenghth"))
breadth=int(input("enter a breadth"))
t=(length*breadth)
print(t)
# Out:
# enter a lenghth45
# enter a breadth56
# 2520

# %%
length=int(input("enter a lenghth"))
breadth=int(input("enter a breadth"))
perimeter=2*(length+breadth)
print(perimeter)
# Out:
# enter a lenghth4
# enter a breadth5
# 18

# %%
radius=float(input("enter a radius"))
area=3.14*radius*radius
print(area)
# Out:
# enter a radius16
# 803.84

# %%
radius=float(input("enter a radius"))
area=2*3.14*radius
print(area)
# Out:
# enter a radius14
# 87.92

# %%
english=int(input("enter a marks"))
math=int(input("enter a marks"))
computer=int(input("enter a marks"))
total=60+80+70
print(total)
# Out:
# enter a marks60
# enter a marks70
# enter a marks80
# 210

# %%
english=int(input("enter a marks"))
math=int(input("enter a marks"))
computer=int(input("enter a marks"))
total=english+math+computer
Percentage=(total/300)*100
print(Percentage)
print(total)
# Out:
# enter a marks54
# enter a marks26
# enter a marks52
# 44.0
# 132

# %%
temp=float(input("enter a temperature"))
fahrenheit=(temp*9/5)+32
print(fahrenheit)
# Out:
# enter a temperature25
# 77.0

# %% [markdown]
# **If else**

# %%
n =int(__builtins__.input("enter a number"))
if n % 2==0:
  print("even")
else:
  print("odd")
# Out:
# enter a number5
# odd

# %%
secound=int(input("enter a secound"))
hours=3665//3600
minute=(3665%3600)//60
secound=(3665%3600)//60
print(hours)
print(minute)
print(secound)
# Out:
# enter a secound55
# 1
# 1
# 1

# %%
minute=int(input("enter a minute"))
hours=3665//3600
remaining=3665%3600
minute=(65%60)
print(hours)
print(minute)
print(remaining)
# Out:
# enter a minute3665
# 1
# 5
# 65

# %%
days=int(input("enetr a days"))
week=365//7
days=365%7
print(week)
print(days)
# Out:
# enetr a days365
# 52
# 1

# %%
reupes=int(input("enter a reupes"))
rupes=380//100
remaining=380%100

reupes=80//50
remaining=80%50

reupes=30//10
remaining=30%10

reupes=20//10
remaining=20%10

reupes=10//10
remaining=10%10


print(rupes)
print(reupes)
print(reupes)
print(reupes)
print(reupes)
print(remaining)
# Out:
# enter a reupes380
# 3
# 1
# 1
# 1
# 1
# 0
